# %%
import pandas as pd

# %%
df_data = pd.read_csv('result.csv')
print('Data Loaded')
# Out:
# Data Loaded

# %%
df_data.iloc[1028:1029,:]
# Out:
#             Date      lng     lat   LSTM_dm  hour   sp   dm  dm_predict AC  \
# 1028  2017-06-12  116.212  39.887  3.179592    23  8.0  0.0         6.0  C
#
#      AC_p AC_LSTM  weekday  weekend_and_holiday
# 1028    B       A        1                    0

# %%
df_data[(df_data.lng == 116.212) & (df_data.lat == 39.887)]
# Out:
#                 Date      lng     lat   LSTM_dm  hour    sp    dm  dm_predict  \
# 1028      2017-06-12  116.212  39.887  3.179592    23   8.0   0.0         6.0
# 76719     2017-06-12  116.212  39.887  4.327640    22   8.0   4.0        10.0
# 152410    2017-06-12  116.212  39.887  5.282469    21   8.0   3.0         4.0
# 228101    2017-06-12  116.212  39.887  5.504483    20   8.0   9.0         5.0
# 303792    2017-06-12  116.212  39.887  5.146139    19   8.0  10.0         5.0
# 379483    2017-06-12  116.212  39.887  4.560120    18   8.0   3.0         7.0
# 455174    2017-06-12  116.212  39.887  4.418822    17   6.0   1.0         4.0
# 530865    2017-06-12  116.212  39.887  4.093738    16   7.0   6.0         8.0
# 606556    2017-06-12  116.212  39.887  3.905242    15   7.0   2.0         2.0
# 682247    2017-06-12  116.212  39.887  3.946250    14   4.0   3.0         2.0
# 757938    2017-06-12  116.212  39.887  4.122675    13   5.0   4.0         2.0
# ...
